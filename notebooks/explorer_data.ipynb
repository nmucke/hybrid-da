# %%
import hybrid_da
import xarray as xr

# %%
data = xr.load_dataset(f'{hybrid_da.__path__[0]}/../../data/raw/unisim-geomec-draft.nc')

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:                    (Date: 31, origin: 1, I: 103, J: 59, K: 120)
# Coordinates:
#   * origin                     (origin) <U12 'CO2_INJECTOR'
#   * Date                       (Date) datetime64[ns] 2025-01-01 ... 2034-01-01
#   * I                          (I) int64 0 1 2 3 4 5 6 ... 97 98 99 100 101 102
#   * J                          (J) int64 0 1 2 3 4 5 6 ... 52 53 54 55 56 57 58
#   * K                          (K) int64 0 1 2 3 4 5 ... 114 115 116 117 118 119
#     xc                         (I, J, K) float64 3.501e+05 ... 3.594e+05
#     yc                         (I, J, K) float64 7.524e+06 ... 7.51e+06
#     zc                         (I, J, K) float64 -221.3 -264.0 ... -5.935e+03
# Data variables: (12/13)
#     Well Bottom-hole Pressure  (Date, origin) float32 nan ... 2.891e+04
#     Gas Rate SC                (Date, origin) float32 nan 1e+04 ... 0.0 0.0
#     DISPLZ                     (Date, I, J, K) float32 0.0 0.0 ... -8.214e-08
# ...
